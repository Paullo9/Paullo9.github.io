# %% [markdown]
# # Load and examine a dataset
# - sample by HW, mesurment by CO
# - high-pressure torsion sample, Ni65Cu35

# %% [markdown]
# # Set environment: Load the packages
# - for details on how to connect to the cluster and set up environments visit paullobpreis.com (pw:4DSTEM)

# %%
# timestr used to create simple timestamps for easier version controll
import time
timestr = time.strftime("%Y%m%d")

# py4dstem as main tool, the follwing command also prints the currently used version
import py4DSTEM
py4DSTEM.__version__
# Out:
# '0.14.16'

# %% [markdown]
# # Load and examine a dataset

# %%
# Load the .dm4 file from a workspace on OMNI or XNAS, set filepath with 'filepath_data = "FILEPATH"'
# even better, use dirpath'' and 'filepath_data', this makes it easier to add more paths later

dirpath = "/Users/paullobpreis/GitHub/Paullo9.github.io/data/"

filepath_data = dirpath + 'COPL_Ni65Cu35_C_ROI3_240827_aper_50_conv_1.5_spot_6_CL_47_stepsize_10_r_x_178_r_y_186_GIF_512x512_preprocessed_unfiltered_bin_4_20240828.h5'

# %%
# Load the datacube from the .dm4 file specified above

# py4DSTEM uses the import_file function to load non-native file formats, while the read function is used for files originally written by py4DSTEM.

datacube = py4DSTEM.import_file(
filepath_data,
)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[38], line 5
#       1 # Load the datacube from the .dm4 file specified above
#       2
#       3 # py4DSTEM uses the import_file function to load non-native file formats, while the read function is used for files originally written by py4DSTEM.
# ----> 5 datacube = py4DSTEM.import_file(
#       6 filepath_data,
#       7 )
#
# File ~/miniconda3/envs/py4dstem/lib/python3.12/site-packages/py4DSTEM/io/importfile.py:68, in import_file(filepath, mem, binfactor, filetype, **kwargs)
#      65 filetype = _parse_filetype(filepath) if filetype is None else filetype
#      67 if filetype in ("emd", "legacy"):
# ---> 68     raise Exception(
#      69         "EMD file or py4DSTEM detected - use py4DSTEM.read, not py4DSTEM.import_file!"
#      70     )
#      71 assert filetype in [
#      72     "dm",
#      73     "empad",
#    (...)
#      78     # "kitware_counted",
#      79 ], "Error: filetype not recognized"
#      81 if filetype == "dm":
#
# Exception: EMD file or py4DSTEM detected - use py4DSTEM.read, not py4DSTEM.import_file!

# %%
# datacube directly passed reveiles the 4-dimensional array of Real Space and Diffaction Space for the sample

datacube
# Out:
# DataCube( A 4-dimensional array of shape (186, 178, 128, 128) called 'dm_dataset',
#           with dimensions:
#
#               Rx = [0.0,5.1,10.2,...] nm
#               Ry = [0.0,5.1,10.2,...] nm
#               Qx = [0.0,0.029196688532829286,0.05839337706565857,...] A^-1
#               Qy = [0.0,0.029196688532829286,0.05839337706565857,...] A^-1
# )

# %%
# The data itself can be observed by the following command:

datacube.data
# Out:
# array([[[[-3.19374451e+02, -9.44956299e+02, -1.77866669e+02, ...,
#           -6.23862488e+02, -6.52326660e+02, -8.65313873e+01],
#          [-3.75145508e+02,  2.62312927e+02,  1.34725540e+02, ...,
#           -1.54536819e+02, -6.74444153e+02, -4.50006775e+02],
#          [-4.00875305e+02, -6.70706665e+02, -2.69619110e+02, ...,
#           -1.36987518e+02, -4.64479706e+02, -2.73969574e+02],
#          ...,
#          [-3.08361420e+02, -1.15247917e+01,  2.37341156e+02, ...,
#            5.42015381e+01, -8.23706665e+02, -3.07181885e+02],
#          [-8.05369415e+01,  8.27563477e+00, -7.19529724e+00, ...,
#            3.49320953e+02, -5.31080704e+01, -6.64651428e+02],
#          [ 8.28704071e+01, -1.89570724e+02, -1.51927139e+02, ...,
#           -8.89043732e+01, -3.42993286e+02, -2.61407227e+02]],
#
#         [[-7.27098389e+01, -3.83761292e+02,  1.74478149e+02, ...,
#           -1.88317245e+02, -2.88742859e+02, -5.10008362e+02],
#          [-1.94731689e+02, -6.48190063e+02, -3.72453583e+02, ...,
#           -4.45353302e+02, -5.16655518e+02, -3.85685455e+02],
#          [-6.65667358e+02, -4.82260742e+02, -2.57130432e+02, ...,
#            8.99043732e+01, -3.52648560e+02, -6.08688049e+02],
#          ...,
#          [-7.18009277e+02, -6.24526062e+02,  4.29598274e+01, ...,
#            1.76588165e+02, -5.00105042e+02, -1.31087845e+02],
#          [-8.76996613e+00, -2.07585953e+02, -2.49074738e+02, ...,
#            2.12778854e+02, -1.67119446e+01,  2.90428558e+02],
#          [-9.12699890e+01, -3.43101135e+02,  6.28641586e+01, ...,
#           -7.72649078e+01, -1.59696320e+02, -1.56881409e+02]],
#
#         [[ 1.45967216e+01,  4.41817207e+01, -5.62117844e+01, ...,
#            5.87992188e+02, -3.67735405e+01,  1.22988510e+02],
#          [-8.33189392e+01,  7.18517227e+01, -1.61290924e+02, ...,
#            3.06637390e+02,  2.31599609e+02,  9.75516319e+00],
#          [ 7.33844910e+01, -6.62805939e+01,  2.33013641e+02, ...,
#            1.13825172e+02, -4.87205597e+02,  2.64403992e+02],
#          ...,
#          [ 9.62617493e+01, -7.95149803e+00, -3.20616211e+02, ...,
#            2.88576752e+02,  4.54371155e+02, -3.99378387e+02],
#          [-1.27056816e+02, -2.90444946e+01,  1.02149612e+02, ...,
#            7.98870621e+01,  3.51635361e+01,  2.39289978e+02],
#          [-2.64340027e+02, -4.44732285e+01,  4.32947784e+02, ...,
#            5.22000000e+02,  5.97369873e+02,  2.34770920e+02]],
#
#         ...,
#
#         [[-9.88489685e+01, -1.24388977e+02, -1.74473465e+02, ...,
#           -4.44756653e+02, -4.76880432e+02, -2.63812195e+02],
#          [-4.88055359e+02, -2.32301147e+02, -3.81170235e+01, ...,
#           -6.96913086e+02,  7.32021713e+01,  3.97956467e+01],
#          [-2.60452332e+02, -3.28390625e+02, -3.23082031e+02, ...,
#           -1.37422882e+02, -1.96272736e+02,  1.46497040e+02],
#          ...,
#          [-3.84911194e+02, -2.88277771e+02, -2.18121246e+02, ...,
#           -5.79498352e+02, -2.50980118e+02, -1.29016495e+02],
#          [-2.67532806e+02, -1.19660675e+02, -8.13809128e+01, ...,
#           -6.14448914e+02, -9.81414185e+01, -2.36671280e+02],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#         [[-4.18868774e+02, -1.46542908e+02, -5.38865845e+02, ...,
#           -7.36709839e+02, -9.91500793e+02, -7.57228760e+02],
#          [-7.12805786e+02, -6.95542847e+02, -7.71671631e+02, ...,
#           -9.85891296e+02, -8.58732056e+02, -4.18621277e+02],
#          [-7.65154297e+02, -7.40494568e+02, -8.95168701e+02, ...,
#           -9.67084290e+02, -9.29963074e+02, -4.40034393e+02],
#          ...,
#          [-3.11392853e+02, -5.54968689e+02, -6.19975891e+02, ...,
#           -2.23248367e+02, -1.00594946e+03, -6.25944763e+02],
#          [-4.73643555e+02, -2.82322815e+02, -2.55026276e+02, ...,
#           -4.67307495e+02, -2.99700592e+02, -2.14554810e+02],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#         [[-1.32956497e+02, -4.83969299e+02, -3.11261993e+02, ...,
#           -3.51545288e+02,  4.36751328e+01, -2.54029770e+02],
#          [-6.37757324e+02, -1.97002487e+02, -5.58567444e+02, ...,
#           -1.76072693e+02,  1.90204269e+02,  4.93448669e+02],
#          [-6.11097168e+02, -3.42858185e+02, -3.72485847e+01, ...,
#           -7.27765808e+01, -1.06996606e+03, -1.39714447e+02],
#          ...,
#          [-3.06187561e+02, -2.43792236e+02, -7.48468140e+02, ...,
#           -7.29559875e+02, -7.12506226e+02, -2.27017548e+02],
#          [-5.40782654e+02, -1.15037003e+02, -1.61144196e+02, ...,
#           -4.77429993e+02, -3.78346191e+02, -2.44923889e+02],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00]]],
#
#
#        [[[-4.65167175e+02, -6.97781372e+02, -6.38683411e+02, ...,
#           -1.60399368e+02, -2.89335419e+02,  5.77832794e+00],
#          [-4.11784180e+02, -7.10427979e+02, -1.91479980e+02, ...,
#           -9.77043274e+02, -4.79622498e+02,  6.06396851e+02],
#          [-2.24121094e+02, -5.90266479e+02, -6.63979492e+01, ...,
#            8.29171295e+01,  2.96599457e+02, -4.01857117e+02],
#          ...,
#          [-1.01314140e+02, -5.55903503e+02, -2.98124725e+02, ...,
#            5.26399109e+02, -6.53899841e+02,  6.76276550e+01],
#          [-3.77641968e+02, -5.02881348e+02, -6.92895264e+02, ...,
#           -8.13550262e+01, -1.31146149e+02, -4.31931152e+02],
#          [ 7.11969299e+01, -1.47180542e+02, -1.04398285e+02, ...,
#           -8.08142456e+02, -1.65520859e+02, -1.58084396e+02]],
#
#         [[-4.47048035e+02, -2.28486557e+02,  1.63268845e+02, ...,
#           -2.96481812e+02, -7.01623718e+02, -3.74304321e+02],
#          [-6.55838470e+01, -4.57814453e+02, -4.94530243e+02, ...,
#           -1.86624969e+02, -9.40471924e+02, -1.96588440e+02],
#          [-3.25931885e+02, -7.71303955e+02, -6.04683350e+02, ...,
#           -1.05925220e+03, -9.34849365e+02,  6.87803162e+02],
#          ...,
#          [-3.12719360e+02, -2.15550232e+02, -3.21664062e+02, ...,
#           -5.10531250e+02, -1.08467749e+03, -1.08623840e+02],
#          [-3.07544739e+02, -5.16224243e+02, -4.99082031e+02, ...,
#           -4.06403809e+02, -5.95627930e+02, -3.64785065e+02],
#          [-1.63267929e+02, -4.44539398e+02, -2.44681854e+02, ...,
#           -4.06951080e+02, -5.80231262e+02, -4.16936684e+01]],
#
#         [[-2.16966980e+02,  2.83461151e+02,  5.68632889e+01, ...,
#           -2.94540955e+02, -6.08971619e+02, -2.34351898e+02],
#          [-1.29914169e+01, -1.60486816e+02, -7.98410492e+01, ...,
#            3.51725586e+02,  6.40496597e+01,  1.93555740e+02],
#          [-6.27283203e+02, -5.41416443e+02, -1.99703552e+02, ...,
#           -3.84625427e+02, -3.39815582e+02, -1.75288284e+02],
#          ...,
#          [-1.51622192e+02, -3.16386505e+02,  2.06199463e+02, ...,
#           -3.74520325e+02, -9.49974487e+02, -5.85800659e+02],
#          [-4.17541321e+02, -3.72115417e+02,  1.05359482e+02, ...,
#            8.24104309e+00, -4.13394989e+02, -2.72313232e+02],
#          [-2.21849091e+02, -3.63999695e+02,  1.71121399e+02, ...,
#           -2.96913422e+02, -1.61160645e+02, -7.19820786e+00]],
#
#         ...,
#
#         [[-1.08416824e+02, -8.36352005e+01, -2.46941162e+02, ...,
#           -2.50881256e+02, -2.33532314e+01, -1.55738754e+02],
#          [-1.03631378e+02, -1.41874634e+02,  2.51345810e+02, ...,
#           -3.13299713e+02,  5.05689758e+02,  1.95833618e+02],
#          [ 6.52278442e+01, -2.18201645e+02,  2.54830780e+02, ...,
#           -1.53696365e+02,  9.16286392e+01, -1.31080505e+02],
#          ...,
#          [-2.86848206e+02,  3.50730209e+01, -5.60240356e+02, ...,
#           -4.95157593e+02, -4.86463989e+02, -2.43719360e+02],
#          [-2.62902466e+02, -1.11816650e+02, -1.97749649e+02, ...,
#           -5.64646118e+02, -1.17277039e+02, -4.12341309e+02],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#         [[ 3.55925964e+02,  3.10181549e+02, -8.22849731e+01, ...,
#           -1.99326096e+02,  2.97697113e+02,  1.96029617e+02],
#          [-5.66769470e+02,  5.33776184e+02,  1.16259941e+02, ...,
#           -2.33828323e+02, -6.23950195e+01,  4.35678802e+02],
#          [-9.00578766e+01, -2.63657959e+02,  3.59393127e+02, ...,
#            2.36409332e+02,  3.64036255e+02, -7.36246643e+01],
#          ...,
#          [ 4.04318504e+01,  6.34975433e+01,  4.46305328e+02, ...,
#           -6.34982300e+02, -1.02035866e+02, -3.13061005e+02],
#          [-2.19760834e+02, -4.51904297e+02, -3.52391998e+02, ...,
#            1.98080582e+02, -5.32531738e-01, -1.01922073e+02],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#         [[-5.18367188e+02, -5.01697998e+02, -6.43139648e+02, ...,
#           -5.74588745e+02, -2.61191437e+02, -8.47466965e+01],
#          [-3.24623016e+02, -4.17803619e+02, -1.54502319e+02, ...,
#           -5.66461426e+02, -3.50858765e+02, -5.42458984e+02],
#          [-5.17549072e+02, -4.65171814e+01,  3.26680481e+02, ...,
#            1.78720261e+02, -5.96487000e+02, -2.04061935e+02],
#          ...,
#          [-2.19918976e+02, -4.29730133e+02,  5.84751358e+01, ...,
#           -3.06134216e+02, -2.91026459e+02, -3.27678436e+02],
#          [-7.41426849e+01, -2.84056793e+02, -4.99064423e+02, ...,
#           -2.26176895e+02,  6.99960632e+01, -2.39488159e+02],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00]]],
#
#
#        [[[-3.19487274e+02, -3.73753204e+02, -4.17518005e+01, ...,
#           -3.66358566e+01, -2.02058289e+02,  3.92293457e+02],
#          [-4.25554565e+02, -9.07948456e+01, -6.73818970e+02, ...,
#            1.06133301e+02, -6.26625610e+02, -1.73788254e+02],
#          [-3.85393738e+02, -7.45787354e+02, -4.18044495e+02, ...,
#           -2.50429688e+02, -6.45681519e+02, -2.37604065e+02],
#          ...,
#          [-4.68455009e+01, -1.35232727e+02,  7.20893784e+01, ...,
#           -7.94683990e+01, -5.54754456e+02, -2.99055023e+02],
#          [-1.54394501e+02,  4.64901886e+01, -4.99085266e+02, ...,
#            1.26110794e+02, -5.60027222e+02, -2.12143799e+02],
#          [-2.45949036e+02, -2.45278229e+02,  1.28805466e+02, ...,
#           -2.98924194e+02,  4.40257416e+01, -4.87779160e+01]],
#
#         [[-1.67044617e+02, -6.42073181e+02, -3.45652313e+02, ...,
#            2.39833832e+02, -1.60969208e+02,  5.81502419e+01],
#          [-1.08803566e+02, -5.11693954e+00, -2.70902405e+01, ...,
#            1.96276123e+02, -1.04815384e+02, -9.28512268e+01],
#          [-3.02682983e+02, -6.50053345e+02, -5.45287048e+02, ...,
#           -2.27647644e+02, -3.85622070e+02,  2.97871094e+01],
#          ...,
#          [-1.57220932e+02, -6.46313110e+02,  7.88444061e+01, ...,
#            1.67984238e+02, -1.29565063e+02, -1.03042038e+02],
#          [ 3.71188316e+01, -4.50340729e+02, -1.83694580e+02, ...,
#            2.25372528e+02, -8.18490845e+02, -8.74934631e+02],
#          [ 1.35429382e+00, -3.27802002e+02,  1.55270844e+02, ...,
#            2.73127197e+02, -2.90875427e+02,  2.59768524e+02]],
#
#         [[-3.65361938e+02,  2.59248138e+02,  2.32921967e+02, ...,
#           -2.72179993e+02, -4.90566315e+02,  2.49648010e+02],
#          [-2.28861847e+02, -2.87558197e+02, -1.85764130e+02, ...,
#           -5.84777588e+02, -4.53272064e+02, -3.37302856e+02],
#          [-2.93150391e+02, -3.43879517e+02, -5.58314209e+02, ...,
#            5.74717773e+02, -4.43311707e+02, -9.03807602e+01],
#          ...,
#          [-3.09311695e+01, -9.90571976e+01,  2.69779327e+02, ...,
#            1.92478714e+02, -7.58687744e+01,  1.21802338e+02],
#          [ 1.75489388e+01,  2.82809052e+02, -2.04554962e+02, ...,
#            3.45853455e+02,  1.95439911e+01,  2.57111481e+02],
#          [-1.95255295e+02,  1.71755844e+02,  2.14314484e+02, ...,
#            1.48400162e+02,  2.87694275e+02, -6.07606277e+01]],
#
#         ...,
#
#         [[ 6.31568970e+02,  2.36411224e+02,  5.24122070e+02, ...,
#            1.51494003e+02,  7.87791626e+02,  4.66425995e+02],
#          [ 1.63842148e+02,  3.44706543e+02, -1.24313755e+01, ...,
#            6.80953735e+02,  6.80925720e+02,  4.00182068e+02],
#          [-1.20419235e+02,  4.17004730e+02,  7.06724487e+02, ...,
#            1.04076553e+02,  4.46101440e+02,  6.85203003e+02],
#          ...,
#          [ 7.86877686e+02,  1.85287033e+02,  4.97952972e+02, ...,
#            1.12291718e+02, -1.72659607e+01, -2.24666672e+02],
#          [ 8.88423157e+00,  2.68708344e+02,  3.31474701e+02, ...,
#            3.23083344e+02,  1.31001938e+02, -2.38491150e+02],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#         [[ 1.02782883e+02,  6.84029541e+02,  3.90655792e+02, ...,
#            2.92563812e+02,  8.18616943e+02,  2.73291016e+02],
#          [ 6.15043945e+02,  1.63524231e+02,  4.83731323e+02, ...,
#            5.26054260e+02,  1.50233826e+02,  4.58820862e+02],
#          [-2.79129333e+01,  5.01527893e+02,  6.09865845e+02, ...,
#            4.71032104e+02,  1.04815051e+03,  2.92920593e+02],
#          ...,
#          [ 3.86170746e+02,  6.25676392e+02, -4.69969177e+01, ...,
#            2.81221741e+02,  5.09176788e+02,  2.31216064e+02],
#          [ 5.58834305e+01,  2.21448364e+02,  5.59697144e+02, ...,
#            4.69537079e+02,  4.32706787e+02, -4.24351654e+01],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#         [[ 3.05496338e+02,  3.53014221e+02,  2.78907318e+02, ...,
#            3.21248169e+01,  6.03541138e+02,  1.20057129e+02],
#          [ 1.23408798e+02,  2.52319733e+02,  2.61469818e+02, ...,
#            1.61403839e+02,  1.39612167e+02,  3.46209595e+02],
#          [ 3.23149109e+02,  2.93950348e+01,  2.40330750e+02, ...,
#            4.16914551e+02,  7.98453186e+02,  6.97047852e+02],
#          ...,
#          [ 6.71364929e+02,  5.82373413e+02,  1.73962067e+02, ...,
#            4.66315765e+02, -1.01567375e+02, -9.46888275e+01],
#          [ 1.85516357e-01,  3.21903320e+02,  6.08699463e+02, ...,
#            3.64199951e+02,  8.98612366e+02,  1.41800354e+02],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00]]],
#
#
#        ...,
#
#
#        [[[-3.72072876e+02, -3.08902649e+02, -3.40793335e+02, ...,
#           -6.49087280e+02, -3.85615082e+02, -7.36221619e+01],
#          [-8.15794144e+01,  1.71495132e+02,  1.22871246e+01, ...,
#            6.91133347e+01, -3.60095764e+02, -5.17310715e+01],
#          [-1.43753815e+02,  2.85034943e+00,  3.67864075e+02, ...,
#            4.22419769e+02,  2.81692078e+02,  1.46040756e+02],
#          ...,
#          [-9.00497437e+01,  7.45182724e+01,  5.85091858e+02, ...,
#           -6.40436783e+01,  5.22624512e+02, -2.85649872e+00],
#          [ 3.29775818e+02, -3.32553864e+02,  2.43650238e+02, ...,
#           -2.18492126e+02, -7.28260681e+02,  5.36667347e+00],
#          [ 5.14989166e+01,  5.17248611e+01, -1.05215454e+00, ...,
#            4.80022736e+01,  4.57917053e+02, -2.09953461e+02]],
#
#         [[-4.81113586e+02, -4.82324142e+01, -2.78857452e+02, ...,
#           -3.22813232e+02, -4.73912048e+01, -6.62685013e+01],
#          [ 4.24622345e+01,  4.29502197e+02,  1.63696854e+02, ...,
#           -2.34260193e+02,  4.44147888e+02, -1.12328438e+02],
#          [-2.48437653e+01, -1.57743195e+02, -5.96777100e+02, ...,
#           -3.87294617e+02, -3.15421295e+02, -2.87875271e+01],
#          ...,
#          [ 1.09397659e+02, -2.26013412e+02, -3.03561554e+02, ...,
#            4.91938995e+02,  1.31216263e+02, -1.49803528e+02],
#          [ 2.31139771e+02,  3.10931335e+02, -3.07561127e+02, ...,
#            4.23186035e+02,  5.52174316e+02, -9.40228271e+01],
#          [ 3.55821716e+02, -3.18401031e+01,  1.10337952e+02, ...,
#           -2.20687653e+02, -1.29871368e+01, -3.47482452e+02]],
#
#         [[-1.62439529e+02,  2.56853546e+02, -7.33111572e+01, ...,
#           -4.25399933e+01,  3.66805084e+02,  1.68341431e+02],
#          [ 3.50605835e+02,  1.69086777e+02, -1.11907379e+02, ...,
#            6.41633545e+02,  2.03728424e+02,  2.58986938e+02],
#          [ 4.57134613e+02,  6.89882812e+02,  3.57319580e+02, ...,
#            1.12642920e+03,  9.16975555e+01,  4.16665497e+01],
#          ...,
#          [ 3.67035004e+02,  2.02837677e+02, -3.45855347e+02, ...,
#           -1.80713165e+02,  4.60997658e+01, -1.31992599e+02],
#          [-2.08236481e+02,  2.03612244e+02,  1.93196671e+02, ...,
#            4.49373169e+02,  4.77941681e+02,  1.40277008e+02],
#          [ 9.14281998e+01,  2.67700317e+02,  1.24168625e+02, ...,
#           -3.38724670e+01,  1.69723953e+02, -5.15989304e+01]],
#
#         ...,
#
#         [[ 5.98641846e+02,  4.69155823e+02,  1.95486267e+02, ...,
#            1.11327995e+02,  4.00912109e+02,  0.00000000e+00],
#          [-4.98787842e+02,  5.21545715e+01, -2.26388672e+02, ...,
#           -3.99228760e+02, -2.82427002e+02,  0.00000000e+00],
#          [-4.82458229e+01, -3.19260101e+01,  9.89268570e+01, ...,
#            1.31063034e+02,  1.07071686e+01,  0.00000000e+00],
#          ...,
#          [ 4.21557709e+02,  1.77047058e+02,  3.72090637e+02, ...,
#            2.74461548e+02,  1.81201996e+02,  0.00000000e+00],
#          [-3.44776306e+01,  2.50415131e+02,  1.02334648e+02, ...,
#            2.99545166e+02, -1.08903809e+02,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#         [[ 3.75268372e+02,  3.03961487e+02,  1.62205856e+02, ...,
#           -7.74440231e+01,  1.97268173e+02,  0.00000000e+00],
#          [ 4.43253876e+02,  1.47302994e+02,  2.09577301e+02, ...,
#            9.75606934e+02,  8.13449768e+02,  0.00000000e+00],
#          [ 3.29368042e+02,  4.56395493e+01,  2.52482880e+02, ...,
#            5.96561157e+02,  3.01829712e+02,  0.00000000e+00],
#          ...,
#          [ 2.07227432e+02,  3.91402893e+02,  4.08217224e+02, ...,
#           -5.07670624e+02,  3.41731140e+02,  0.00000000e+00],
#          [-3.89091797e+01,  9.42526321e+01,  9.72676849e+01, ...,
#            1.57333740e+02,  1.13170166e+02,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#         [[ 7.30146484e+01,  2.58720825e+02,  3.74628906e+01, ...,
#            5.50152649e+02,  3.29100830e+02,  0.00000000e+00],
#          [-7.68963394e+01,  3.75755127e+02,  6.09051880e+02, ...,
#           -1.32989655e+02,  1.37880676e+02,  0.00000000e+00],
#          [ 6.80436646e+02,  5.61882385e+02,  1.52077759e+02, ...,
#            4.08424927e+02,  8.01680847e+02,  0.00000000e+00],
#          ...,
#          [ 5.14566284e+02,  5.32777405e+02,  2.79674408e+02, ...,
#            4.73256134e+02,  5.02723053e+02,  0.00000000e+00],
#          [ 4.47877258e+02,  4.07186829e+02,  6.08761353e+02, ...,
#            4.45475098e+02,  2.30034012e+02,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00]]],
#
#
#        [[[ 1.97227814e+02,  2.13203033e+02,  4.62100494e+02, ...,
#            5.95828552e+01,  3.53671509e+02,  6.42980347e+01],
#          [ 4.02722839e+02,  1.63679169e+02, -4.66400909e+01, ...,
#           -9.86117325e+01,  6.57662476e+02,  5.09347534e+01],
#          [ 1.13962433e+02,  2.74260590e+02, -1.28583725e+02, ...,
#           -4.89551910e+02,  5.58171753e+02,  7.86726456e+01],
#          ...,
#          [-1.15247650e+02,  3.92411652e+02,  5.93313141e+01, ...,
#           -2.19658478e+02, -3.22872772e+01,  9.40678787e+01],
#          [-9.66719666e+01,  3.97616455e+02, -1.16631477e+02, ...,
#           -5.27829041e+02,  6.42655029e+02, -1.88790283e+02],
#          [-2.11834167e+02, -1.64956436e+01,  6.82809067e+01, ...,
#            1.54469681e+02, -3.36089539e+02,  9.97931366e+01]],
#
#         [[-2.99324951e+02, -1.46391235e+02,  9.10144119e+01, ...,
#           -2.60213806e+02, -2.90083801e+02, -4.46885452e+01],
#          [-3.53415222e+02,  1.69233734e+02,  3.41501236e+01, ...,
#           -5.32749634e+01, -2.64815094e+02, -4.36182289e+01],
#          [-1.21890755e+01, -1.32895905e+02,  1.93160828e+02, ...,
#           -1.09598694e+02, -2.27996063e+01,  2.59306885e+02],
#          ...,
#          [ 4.84410461e+02,  2.89371891e+01, -1.32345245e+02, ...,
#           -5.43462097e+02,  4.27186157e+02,  4.62119865e+01],
#          [ 7.83566208e+01,  1.36869583e+01, -2.37512341e+01, ...,
#           -1.42873108e+02,  3.86430420e+02, -1.12043327e+02],
#          [-1.47945450e+02,  5.73354645e+01,  5.93172607e+02, ...,
#            2.75515350e+02,  6.52142456e+02,  1.62227661e+02]],
#
#         [[ 7.34853363e+01, -5.39071472e+02, -2.83932617e+02, ...,
#            4.15733582e+02,  3.61140442e+02,  2.04061630e+02],
#          [ 5.46988792e+01, -7.01432800e+00,  4.34727554e+01, ...,
#           -2.64519409e+02, -2.97466370e+02, -2.47994308e+01],
#          [-3.25257507e+02, -2.98432068e+02, -5.96484375e+02, ...,
#            4.24304993e+02, -6.75972473e+02, -1.79217773e+02],
#          ...,
#          [ 3.51973083e+02, -4.30197998e+02,  2.80109711e+02, ...,
#           -4.08151245e+02,  2.06314865e+02,  1.27371933e+02],
#          [ 4.90621735e+02, -6.17661621e+02,  1.55356354e+02, ...,
#            1.37806351e+02,  1.51402740e+02,  6.32768173e+01],
#          [-1.61850281e+01,  8.88564072e+01, -1.64426132e+02, ...,
#            3.45094238e+02, -3.63945068e+02, -1.62953674e+02]],
#
#         ...,
#
#         [[-2.09915878e+02, -1.33610779e+02,  6.40628052e+02, ...,
#           -3.11295624e+02, -3.14961639e+02,  0.00000000e+00],
#          [ 7.51488495e+01, -2.01828583e+02,  9.66117859e+00, ...,
#           -2.70038727e+02,  6.75294495e+01,  0.00000000e+00],
#          [-8.92723236e+01,  3.83597839e+02,  3.47413902e+01, ...,
#            2.91509705e+02, -3.60090332e+01,  0.00000000e+00],
#          ...,
#          [ 3.00554443e+02,  5.47699036e+02,  2.08470573e+01, ...,
#            2.88508087e+02,  2.61528503e+02,  0.00000000e+00],
#          [ 4.43776932e+01,  5.20224495e+01,  3.61011734e+01, ...,
#            2.36653915e+02, -1.04547508e+02,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#         [[ 5.09673729e+01,  2.56741543e+01, -4.34524841e+02, ...,
#            2.48182411e+01,  3.47423210e+01,  0.00000000e+00],
#          [-6.42777954e+02, -2.42707870e+02, -2.63607117e+02, ...,
#           -3.10363495e+02,  1.11208679e+02,  0.00000000e+00],
#          [-5.41100281e+02,  1.22210350e+01,  1.82068329e+02, ...,
#            3.99910583e+02,  1.01749977e+02,  0.00000000e+00],
#          ...,
#          [ 3.27330139e+02,  1.72159943e+02, -3.73692261e+02, ...,
#           -3.56583191e+02, -2.43581787e+02,  0.00000000e+00],
#          [ 1.24428619e+02,  1.71112442e+02,  1.46576080e+02, ...,
#            2.99426651e+00,  5.60066700e+00,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#         [[ 9.82745667e+01,  6.48407654e+02,  3.94084808e+02, ...,
#            6.98472717e+02,  1.04757617e+03,  0.00000000e+00],
#          [ 2.79450348e+02,  4.29937714e+02,  1.91126999e+02, ...,
#            5.19406700e+01,  7.18043091e+02,  0.00000000e+00],
#          [ 4.01667938e+01, -2.01084015e+02, -2.21179352e+01, ...,
#            1.02069275e+02,  5.93403442e+02,  0.00000000e+00],
#          ...,
#          [ 9.27026306e+02,  4.18899139e+02,  2.68888092e+02, ...,
#            1.92138641e+02,  1.79405289e+01,  0.00000000e+00],
#          [ 3.40177582e+02,  3.56125946e+01,  3.25013275e+01, ...,
#            1.05928856e+02,  2.08913208e+02,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00]]],
#
#
#        [[[ 1.12375153e+02, -5.44719009e+01,  2.35568512e+02, ...,
#           -3.74909760e+02,  6.64161682e+00,  2.81242390e+01],
#          [ 2.05415070e+02,  1.68691498e+02, -1.15708557e+02, ...,
#           -5.98386192e+01,  4.13319244e+02, -4.42839813e+01],
#          [ 3.08650208e+02,  2.17419250e+02, -1.61790710e+02, ...,
#            7.80499512e+02,  5.85876404e+02,  2.46783844e+02],
#          ...,
#          [-3.38821350e+02, -9.44925537e+01,  7.13762207e+02, ...,
#           -1.06578621e+02,  9.35456360e+02,  6.26076508e+01],
#          [ 4.43585938e+02, -1.32552948e+02,  2.23301224e+02, ...,
#            2.88842102e+02,  7.24529846e+02,  2.23663879e+02],
#          [-2.79352203e+02,  4.08185303e+02,  3.83529022e+02, ...,
#           -3.52284546e+01,  2.21215302e+02,  2.24184296e+02]],
#
#         [[-7.60436890e+02,  1.33139481e+02, -2.39289581e+02, ...,
#            4.40690704e+02,  9.28979797e+01,  9.01531754e+01],
#          [-3.79212219e+02, -1.41945419e+02,  2.63283875e+02, ...,
#           -1.31908768e+02,  2.77151489e+02,  1.10341415e+02],
#          [-1.62415100e+02,  1.58229614e+02, -1.83488846e+02, ...,
#            5.47798096e+02,  2.71326172e+02,  1.81057549e+00],
#          ...,
#          [ 1.17216766e+02, -6.54195480e+01, -6.75174805e+02, ...,
#           -3.21724518e+02,  7.91074295e+01, -2.29417324e+00],
#          [ 1.23088348e+02, -1.13150856e+02,  1.88574677e+02, ...,
#           -2.17064362e+01, -2.91317169e+02, -2.35946625e+02],
#          [ 2.69778503e+02,  1.10881302e+02,  2.29185074e+02, ...,
#            4.14876648e+02, -1.42958130e+02, -3.41235733e+01]],
#
#         [[ 5.65284615e+01, -1.05416649e+02, -6.40024185e+01, ...,
#            5.82398872e+01, -5.51565247e+01,  7.36155701e+01],
#          [-1.95345459e+02,  9.98519440e+01, -3.35273651e+02, ...,
#           -5.18608276e+02, -8.65149689e+01, -1.19876175e+02],
#          [-7.60955383e+02, -2.17352707e+02, -3.22805908e+02, ...,
#           -2.27894043e+02,  3.60466125e+02,  1.18696869e+02],
#          ...,
#          [ 4.97099152e+01,  7.43077850e+01, -3.48498306e+01, ...,
#            2.64996765e+02,  2.78024292e+02,  6.35427170e+01],
#          [ 1.09666862e+01,  3.62576599e+02, -1.57198288e+02, ...,
#            7.16336060e+01,  5.89444824e+02, -3.38025951e+00],
#          [-1.58082703e+02, -1.05489662e+02,  2.08111935e+01, ...,
#           -4.27599121e+02,  4.18602448e+02,  1.29383316e+01]],
#
#         ...,
#
#         [[ 2.03948608e+02,  5.71964172e+02,  2.24222351e+02, ...,
#            6.26355400e+01,  1.63297241e+02,  0.00000000e+00],
#          [ 1.01121460e+02,  5.24601288e+01,  1.68892929e+02, ...,
#           -2.44427139e+02,  5.61689453e+02,  0.00000000e+00],
#          [ 6.47301636e+02, -3.50417709e+01,  3.20760223e+02, ...,
#            4.04363403e+02,  1.28958649e+02,  0.00000000e+00],
#          ...,
#          [ 2.85381470e+02,  1.12140617e+01, -7.45220154e+02, ...,
#            1.73931458e+02,  2.98781799e+02,  0.00000000e+00],
#          [ 2.56866150e+01, -1.28038971e+02, -7.14123230e+01, ...,
#            2.39059708e+02,  2.57027893e+01,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#         [[-4.79771515e+02, -1.16447205e+02,  4.18642426e+00, ...,
#            2.09706482e+02, -4.99001740e+02,  0.00000000e+00],
#          [ 2.51679352e+02, -3.15368164e+02,  1.67290344e+01, ...,
#            5.49837585e+02,  1.61449509e+02,  0.00000000e+00],
#          [ 1.89870728e+02,  2.10555420e+01, -1.44633163e+02, ...,
#            2.91848846e+02,  5.13559875e+02,  0.00000000e+00],
#          ...,
#          [-1.81580292e+02,  1.92372757e+02,  7.05458130e+02, ...,
#           -5.44367004e+02, -9.01835632e+00,  0.00000000e+00],
#          [ 4.09936066e+01,  2.05210403e+02,  8.62999535e+00, ...,
#            8.86886978e+00,  1.77670715e+02,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#         [[ 1.34329590e+02,  1.64704956e+02,  1.28633942e+02, ...,
#            6.03029663e+02, -1.43639374e+02,  0.00000000e+00],
#          [ 1.96774673e+02,  4.14741791e+02,  1.38121902e+02, ...,
#            1.44865341e+02, -8.36948853e+01,  0.00000000e+00],
#          [-1.02699463e+02,  7.90902252e+01,  4.39884430e+02, ...,
#            3.69484619e+02,  7.25917236e+02,  0.00000000e+00],
#          ...,
#          [ 3.06152283e+02,  3.68390381e+02,  2.19609283e+02, ...,
#           -1.75521210e+02,  2.54934845e+02,  0.00000000e+00],
#          [ 1.32929840e+02,  2.62028900e+02,  5.07762527e+00, ...,
#            1.18473816e+01, -5.44651031e+01,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00]]]],
#       dtype=float32)

# %% [markdown]
# # Bin-on-load
# Binnig is an option for large datasets that might not fit the computers RAM, hopefully we can skip this part as we are using the OMNI cluster.

# %%
# this would turn a 128x128 dataset into a 64x64 dataset, hence 8 times smaller

datacube_binned = py4DSTEM.read(
   filepath_data,
   binfactor = 2
)

datacube_binned
# Out:
# DataCube( A 4-dimensional array of shape (186, 178, 128, 128) called 'dm_dataset',
#           with dimensions:
#
#               Rx = [0.0,5.1,10.2,...] nm
#               Ry = [0.0,5.1,10.2,...] nm
#               Qx = [0.0,0.029196688532829286,0.05839337706565857,...] A^-1
#               Qy = [0.0,0.029196688532829286,0.05839337706565857,...] A^-1
# )

# %% [markdown]
# # Calibrate pixel size and unit

# %%
# several properties of our datacube can be shown by:
print(datacube.data.shape)
print(datacube.shape)
print(datacube.Rshape)
print(datacube.Qshape)
# Out:
# (186, 178, 128, 128)
# (186, 178, 128, 128)
# (186, 178)
# (128, 128)

# %%
# Vectors calibrating each dimension of the dataset are included within the datacube, utilizing any available calibrations retrieved from the file

# dimension vectors -
print('The first dimension:')
print(f'  - dimension name: {datacube.dim_names[0]}')
print(f'  - dimension units: {datacube.dim_units[0]}')
print(f'  - dim vector: {datacube.dims[0][:10]}') # note the `[:10]` - we're only displaying the first 10 entries
print()
print('The third dimension:')
print(f'  - dimension name: {datacube.dim_names[2]}')
print(f'  - dimension units: {datacube.dim_units[2]}')
print(f'  - dim vector: {datacube.dims[2][:10]}')

print()

# pixel sizes -
qpix = datacube.calibration.get_Q_pixel_size()
qpixunit = datacube.calibration.get_Q_pixel_units()
rpix = datacube.calibration.get_R_pixel_size()
rpixunit = datacube.calibration.get_R_pixel_units()
print()
print(f"The diffraction space pixels are each {qpix:.4f} {qpixunit}")
print(f"The real space pixels are each {rpix:.4f} {rpixunit}")
# Out:
# The first dimension:
#   - dimension name: Rx
#   - dimension units: nm
#   - dim vector: [ 0.   5.1 10.2 15.3 20.4 25.5 30.6 35.7 40.8 45.9]
#
# The third dimension:
#   - dimension name: Qx
#   - dimension units: A^-1
#   - dim vector: [0.         0.02919669 0.05839338 0.08759007 0.11678675 0.14598344
#  0.17518013 0.20437682 0.23357351 0.2627702 ]
#
#
# The diffraction space pixels are each 0.0292 A^-1
# The real space pixels are each 5.1000 nm

# %%
# complete list of calibrations is located here; the above vectors are derived from these values

datacube.calibration
# Out:
# Calibration( A Metadata instance called 'calibration', containing the following fields:
#
#              Q_pixel_size:     0.029196688532829286
#              R_pixel_size:     5.1
#              Q_pixel_units:    A^-1
#              R_pixel_units:    nm
#              QR_flip:          False
#              _root_treepath:
# )

# %%
# Currently, the real space pixel size is shown as 1 pixel, indicating that this information was either unavailable or not extracted from the .dm4 file.
# Assuming we know the real space pixel size between beam positions is 5 nanometers, we can update the value using:

datacube.calibration.set_R_pixel_size(5.1)
datacube.calibration.set_R_pixel_units('nm')

# and print the newly calibrated values with:
datacube.calibration

# the values will be automatically updated in the datacube
# Out:
# Calibration( A Metadata instance called 'calibration', containing the following fields:
#
#              Q_pixel_size:     0.029196688532829286
#              R_pixel_size:     5.1
#              Q_pixel_units:    A^-1
#              R_pixel_units:    nm
#              QR_flip:          False
#              _root_treepath:
# )

# %% [markdown]
# # Filterung and removing hot pixels, probably not needed

# %%
# The function works by finding pixels in the mean diffraction image that are thresh times brighter than any other pixel in their local neighborhood.
# It then replaces these hot pixels in each diffraction pattern with the local median intensity.

datacube.filter_hot_pixels(
    thresh = 8
)
# Out:
# Cleaning pixels: 100%|██████████| 33108/33108 [00:42<00:00, 786.66 images/s]
# DataCube( A 4-dimensional array of shape (186, 178, 128, 128) called 'dm_dataset',
#           with dimensions:
#
#               Rx = [0.0,5.1,10.2,...] nm
#               Ry = [0.0,5.1,10.2,...] nm
#               Qx = [0.0,0.029196688532829286,0.05839337706565857,...] A^-1
#               Qy = [0.0,0.029196688532829286,0.05839337706565857,...] A^-1
# )

# %% [markdown]
# # Binning in diffraction space
# Loading unbinned data and bin it later is prefered, here is a function to do so, the binning factor is given in parentheses

# %%
datacube.bin_Q(4)
# Out:
# DataCube( A 4-dimensional array of shape (186, 178, 32, 32) called 'dm_dataset',
#           with dimensions:
#
#               Rx = [0.0,5.1,10.2,...] nm
#               Ry = [0.0,5.1,10.2,...] nm
#               Qx = [0.0,0.11678675413131714,0.2335735082626343,...] A^-1
#               Qy = [0.0,0.11678675413131714,0.2335735082626343,...] A^-1
# )

# %% [markdown]
# # Save the modified data
# - Now we set a new filepath consisting of the old path with additions indicating our processing
# - from the name alone should be clear if we preprosessed/filtered/binned
# - additionalls I implemented timestr to include the date

# %%
# this data is saved as a .h5 file format 

from os.path import splitext
filepath_save = splitext(filepath_data)[0] + '_preprocessed_unfiltered_bin_4_' + timestr + '.h5'


# print the new filepath 

print(filepath_save)
# Out:
# /Users/paullobpreis/GitHub/Paullo9.github.io/data/COPL_Ni65Cu35_C_ROI3_240827_aper_50_conv_1.5_spot_6_CL_47_stepsize_10_r_x_178_r_y_186_GIF_512x512_preprocessed_unfiltered_bin_4_20240828_preprocessed_unfiltered_bin_4_20240925.h5

# %%
# Save

py4DSTEM.save(
    filepath_save,
    datacube,
    mode = 'o'    # 'overwrite' mode
)

# %% [markdown]
# # Inspect the resulting HDF5 file
# - first we want to see where the data lives without opening it
# - secondly we check which default name was assigned

# %%
# 'dm_dataset' and 'dm_dataset_root' are placeholders we could re-assigning a different name later

py4DSTEM.print_h5_tree(filepath_save)

datacube.name
# Out:
# /
# |---dm_dataset_root
#     |---dm_dataset
# 'dm_dataset'

# %% [markdown]
# # Note
# - When deciding whether or not to save a datacube to storage, it's important to be mindful of the necessity. Since datacubes are typically large and accessible from the original microscope file, avoid creating new files unless there is a compelling reason.
